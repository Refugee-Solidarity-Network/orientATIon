# %% [markdown]
# # Generate Question-and-Answer Pairs
# This notebook generates Question-Answer pairs from an existing base-truth document.
#
# **Attribution:** Code is taken and adapted from [LangChain Auto-Evaluator]().

# %%
import itertools
import random
from langchain.llms import Bedrock
from langchain.chains import QAGenerationChain
import boto3

# Define the Bedrock Client
def get_bedrock_client():
    bedrock_client = boto3.client("bedrock-runtime", region_name="us-east-1")
    return bedrock_client

# Instantiate LLM with Cohere Model
llm = Bedrock(
    client=get_bedrock_client(),
    model_id="cohere.command-text-v14"
)

def generate_eval(text, chunk):
    """
    Generate question-answer pair from input text 
    @param text: text to generate eval set from
    @param chunk: chunk size to draw question from text
    @return: dict with keys "question" and "answer"
    """

    # Check if there are enough characters in the text
    if len(text) < chunk:
        raise ValueError("Input text is too short for the specified chunk size")

    # Generate random starting index in the doc to draw a question from
    num_of_chars = len(text)
    starting_index = random.randint(0, num_of_chars - chunk)
    sub_sequence = text[starting_index:starting_index + chunk]
    
    # Set up QAGenerationChain chain using Cohere Command
    chain = QAGenerationChain.from_llm(llm)
    
    # Catch any QA generation errors and re-try until a QA pair is generated
    awaiting_answer = True
    while awaiting_answer:
        try:
            qa_pair = chain.run(sub_sequence)
            awaiting_answer = False
        except JSONDecodeError:
            print("Error on question")
            starting_index = random.randint(0, num_of_chars - chunk)
            sub_sequence = text[starting_index:starting_index + chunk]
    
    eval_pair = {
        "question": qa_pair[0]["question"],
        "answer": qa_pair[0]["answer"]
    }
    return eval_pair

def generate_eval_pairs(texts, chunk_size, num_pairs):
    """
    Generate a specified number of question-answer pairs.
    @param texts: Input text to generate pairs from
    @param chunk_size: Chunk size to draw questions from the text
    @param num_pairs: Number of pairs to generate
    @return: List of dictionaries with keys "question" and "answer"
    """
    eval_pairs = []
    for _ in range(num_pairs):
        eval_pair = generate_eval(texts, chunk_size)
        eval_pairs.append(eval_pair)
    return eval_pairs

# Specify the number of pairs you want to generate
num_pairs_to_generate = 10

# Generate the specified number of question-answer pairs
generated_pairs = generate_eval_pairs(text, 3000, num_pairs_to_generate)

# Print the generated pairs
for i, pair in enumerate(generated_pairs, start=1):
    print(f"Pair {i}:")
    print(f"Question: {pair['question']}")
    print(f"Answer: {pair['answer']}\n")
# Out:
# Pair 1:
# Question: What are the different ways to apply for the Feedback and Complaint mechanism?
# Answer: [Using their Feedback and Complaints Hotline: +90 0543 329 61 90, SMS, Whatsapp, Telegram, Signal or Viber. Emailing either geribildirim-sikayet@mhd.org.tr or feedback-complaints@mhd.org.tr. Or filling out one of their online forms, found here: https://docs.google.com/forms/d/e/1FAIpQLScfDQVudLlDha6nMACBoTwDLE2YWNscWjd2OzWOOOnBXIUsTQ/viewform (Turkish), https://docs.google.com/forms/d/e/1FAIpQLSc76wSwaQCenUQD1yKIhRyrs565grkiiO3ndKfleHTuBAfRZg/viewform (English), https://docs.google.com/forms/d/e/1FAIpQLSdTRAMZgfgJ4lnPlMw2kN97U4Jb6ANN5mbphl1glrfFWMzZLQ/viewform (French), https://docs.google.com/forms/d/e/1FAIpQLSdu7Euqd2qeeCJwojRJ3KGQ3wZXUuZlugSe4FxAlcjgytey-Q/viewform (Arabic), or https://docs.google.com/forms/d/e/1FAIpQLSfHq0keZ24iFQwU3FYfDvr8U0d-Q7V3XKcB9f5MG7QUidsowQ/viewform (Farsi)]
#
# Pair 2:
# Question: Under what circumstances would I be eligible for free legal aid in Turkey?
# Answer: If a person cannot afford to pay for a lawyer and legal fees without causing considerable financial strain on themselves or their family.
#
# Pair 3:
# Question: What am I entitled to before and after my 18th birthday?
# Answer: Minors have access to shelter, food, clothing, medical care, education, and pocket money. Upon turning 18, asylum seekers have access to less government-funded support, though accommodation, food, and medical care may be provided if the asylum seeker has special circumstances.
#
# Pair 4:
# Question: What issues should be contemplated before entering into a rental contract?
# Answer: It is important to make sure that you are negotiating and signing a contract with the rightful lessor or their authorized agent. The contact details of the landlord and the address of the rented property should also match the information on the title deed. Make sure that the terms of the contract have been thoroughly discussed and understood. This includes the rent cost, the method of payment, the date of payment, the terms of the security deposit, and the state of the property being rented. All of these considerations help avoid misunderstandings down the line.
#
# Pair 5:
# Question: What happens after my 18th birthday in regards to living arrangements?
# Answer: Upon turning 18, you are expected to find your own accommodations and provide for your own living expenses as an adult. This is due to Turkey's current practices of expecting adult asylum seekers to be independent.
#
# Pair 6:
# Question: What are my options for seeking asylum in Turkey?
# Answer: As a refugee, you may seek asylum in Turkey by registering for either temporary protection or international protection. This protection status ensures that you will not be deported back to your country of origin while your application is reviewed.
#
# Pair 7:
# Question: What is important for beneficiaries to understand about the services provided by this organization?
# Answer: The organization provides legal assistance and they have explicitly stated that they provide clear and accurate information on the scope of their services. They also emphasize that their services are free, and they ask beneficiaries to disregard any claims to the contrary. They also stress that their staff does not accept any gifts or favors in order to avoid any perceptions of unfairness or bias.
#
# Pair 8:
# Question: What happens after my 18th birthday in terms of accommodation?
# Answer: Once an individual turns 18, they are considered an adult in the eyes of the law and are expected to find their own accommodation and provide for their own living expenses. However, there might be a possibility for a short-term extension of stay at the facility for a certain period after turning 18 if you can demonstrate the need for it, such as pursuing education or if exceptional circumstances apply (e.g. awaiting family reunification). The decision and duration of such extensions are made on a case-by-case basis and depend on facility capacity and judicial approval.
#
# Pair 9:
# Question: What should happen after I get released from the removal center?
# Answer: The authorities should inform you in writing about your release, status in Turkey, rights, entitlements, and any duties you might have.
#
# Pair 10:
# Question: What is the purpose of registering with the Turkish authorities?
# Answer: Registration allows you to stay legally in Turkey and access public services under the temporary protection regime. It is also required if you want to travel outside of Turkey.
